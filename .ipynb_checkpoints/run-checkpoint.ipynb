# %%
import json
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense
from keras.optimizers import sgd


class Catch(object):
    def __init__(self, grid_size=10):
        self.grid_size = grid_size
        self.reset()

    def _update_state(self, action):
        """
        Input: action and states
        Ouput: new states and reward
        """
        state = self.state
        # 0 = left
        # 1 = right
        # 2 = down
        # 3 = up
        direction_x = 0
        direction_y = 0
        
        fy, fx, py, px, t = state
        
        if action == 0:
            if px > 0:
                px -= 1
        if action == 1:
            if px < self.grid_size-1:
                px += 1
        if action == 2:
            if py > 0:
                py-= 1
        if action == 3:
            if py < self.grid_size-1:
                py += 1
                
        
        out = np.array([fy, fx, py, px, t-1])
        self.state = out

    def _draw_state(self):
        im_size = (self.grid_size,)*2
        state = self.state
        canvas = np.zeros(im_size)
        canvas[state[0], state[1]] = 1  # draw fruit
        canvas[state[2], state[3]] = 0.5  # draw basket
        return canvas

    def _get_reward(self):
        fruit_y, fruit_x, player_y, player_x, t = self.state
        if fruit_x == player_x and fruit_y == player_y:
            return 1
        else:
            return 0

    def _is_over(self):
        if self.state[4] == 0:
            return True
        else:
            return False

    def observe(self):
        canvas = self._draw_state()
#         print(self.state)
#         print(canvas)
#         input("!")
        return canvas.reshape((1, -1))

    def act(self, action):
        self._update_state(action)
        reward = self._get_reward()
        game_over = self._is_over()
        return self.observe(), reward, game_over

    def reset(self):
        fruit_x = np.random.randint(0, self.grid_size-1)
        fruit_y = np.random.randint(0, self.grid_size-1)
        player_x = np.random.randint(0, self.grid_size-1)
        player_y = np.random.randint(0, self.grid_size-1)
        self.state = np.asarray([fruit_y, fruit_x, player_y, player_x, 10])


class ExperienceReplay(object):
    def __init__(self, max_memory=100, discount=.9):
        self.max_memory = max_memory
        self.memory = list()
        self.discount = discount

    def remember(self, states, game_over):
        # memory[i] = [[state_t, action_t, reward_t, state_t+1], game_over?]
        self.memory.append([states, game_over])
        if len(self.memory) > self.max_memory:
            del self.memory[0]

    def get_batch(self, model, batch_size=10):
        len_memory = len(self.memory)
        num_actions = model.output_shape[-1]
        env_dim = self.memory[0][0][0].shape[1]
        inputs = np.zeros((min(len_memory, batch_size), env_dim))
        targets = np.zeros((inputs.shape[0], num_actions))
        for i, idx in enumerate(np.random.randint(0, len_memory,
                                                  size=inputs.shape[0])):
            state_t, action_t, reward_t, state_tp1 = self.memory[idx][0]
            game_over = self.memory[idx][1]

            inputs[i:i+1] = state_t
            # There should be no target values for actions not taken.
            # Thou shalt not correct actions not taken #deep
            targets[i] = model.predict(state_t)[0]
            Q_sa = np.max(model.predict(state_tp1)[0])
            if game_over:  # if game_over is True
                targets[i, action_t] = reward_t
            else:
                # reward_t + gamma * max_a' Q(s', a')
                targets[i, action_t] = reward_t + self.discount * Q_sa
        return inputs, targets


if __name__ == "__main__":
    # parameters
    epsilon = .1  # exploration
    num_actions = 4  # [move_left, stay, move_right]
    epoch = 1000
    max_memory = 500
    hidden_size = 100
    batch_size = 50
    grid_size = 10

    model = Sequential()
    model.add(Dense(hidden_size, input_shape=(grid_size**2,), activation='relu'))
    model.add(Dense(hidden_size, activation='relu'))
    model.add(Dense(num_actions))
    model.compile(sgd(lr=.2), "mse")

    # If you want to continue training from a previous model, just uncomment the line bellow
    # model.load_weights("model.h5")

    # Define environment/game
    env = Catch(grid_size)

    # Initialize experience replay object
    exp_replay = ExperienceReplay(max_memory=max_memory)

    # Train
    win_cnt = 0
    for e in range(epoch):
        loss = 0.
        env.reset()
        game_over = False
        # get initial input
        input_t = env.observe()

        while not game_over:
            input_tm1 = input_t
            # get next action
            if np.random.rand() <= epsilon:
                action = np.random.randint(0, num_actions, size=1)
            else:
                q = model.predict(input_tm1)
                action = np.argmax(q[0])

            # apply action, get rewards and new state
            input_t, reward, game_over = env.act(action)
            if reward == 1:
                win_cnt += 1

            # store experience
            exp_replay.remember([input_tm1, action, reward, input_t], game_over)

            # adapt model
            inputs, targets = exp_replay.get_batch(model, batch_size=batch_size)

            loss += model.train_on_batch(inputs, targets)
        print("Epoch {:03d}/999 | Loss {:.4f} | Win count {}".format(e, loss, win_cnt))

    # Save trained model weights and architecture, this will be used by the visualization code
    model.save_weights("model.h5", overwrite=True)
    with open("model.json", "w") as outfile:
        json.dump(model.to_json(), outfile)
# Out:
# Epoch 000/999 | Loss 0.0141 | Win count 0
# Epoch 001/999 | Loss 0.1809 | Win count 1
# Epoch 002/999 | Loss 0.1261 | Win count 1
# Epoch 003/999 | Loss 0.0867 | Win count 1
# Epoch 004/999 | Loss 0.0817 | Win count 1
# Epoch 005/999 | Loss 0.0712 | Win count 1
# Epoch 006/999 | Loss 0.0385 | Win count 1
# Epoch 007/999 | Loss 0.0337 | Win count 1
# Epoch 008/999 | Loss 0.0452 | Win count 1
# Epoch 009/999 | Loss 0.0187 | Win count 1
# Epoch 010/999 | Loss 0.0199 | Win count 1
# Epoch 011/999 | Loss 0.0246 | Win count 1
# Epoch 012/999 | Loss 0.0187 | Win count 1
# Epoch 013/999 | Loss 0.0230 | Win count 1
# Epoch 014/999 | Loss 0.0164 | Win count 1
# Epoch 015/999 | Loss 0.0470 | Win count 4
# Epoch 016/999 | Loss 0.0523 | Win count 4
# Epoch 017/999 | Loss 0.0488 | Win count 4
# Epoch 018/999 | Loss 0.0627 | Win count 4
# Epoch 019/999 | Loss 0.0531 | Win count 4
# Epoch 020/999 | Loss 0.0306 | Win count 4
# Epoch 021/999 | Loss 0.0440 | Win count 4
# Epoch 022/999 | Loss 0.0402 | Win count 4
# Epoch 023/999 | Loss 0.0499 | Win count 4
# Epoch 024/999 | Loss 0.0453 | Win count 4
# Epoch 025/999 | Loss 0.0639 | Win count 4
# Epoch 026/999 | Loss 0.0289 | Win count 4
# Epoch 027/999 | Loss 0.0172 | Win count 4
# Epoch 028/999 | Loss 0.0260 | Win count 4
# Epoch 029/999 | Loss 0.0324 | Win count 4
# Epoch 030/999 | Loss 0.0212 | Win count 4
# Epoch 031/999 | Loss 0.0299 | Win count 4
# Epoch 032/999 | Loss 0.0228 | Win count 4
# Epoch 033/999 | Loss 0.0298 | Win count 4
# Epoch 034/999 | Loss 0.0352 | Win count 4
# Epoch 035/999 | Loss 0.0298 | Win count 4
# Epoch 036/999 | Loss 0.0189 | Win count 4
# Epoch 037/999 | Loss 0.0252 | Win count 4
# Epoch 038/999 | Loss 0.0250 | Win count 4
# Epoch 039/999 | Loss 0.0246 | Win count 4
# Epoch 040/999 | Loss 0.0228 | Win count 4
# Epoch 041/999 | Loss 0.0201 | Win count 4
# Epoch 042/999 | Loss 0.0157 | Win count 5
# Epoch 043/999 | Loss 0.0173 | Win count 5
# Epoch 044/999 | Loss 0.0267 | Win count 5
# Epoch 045/999 | Loss 0.0449 | Win count 5
# Epoch 046/999 | Loss 0.0217 | Win count 5
# Epoch 047/999 | Loss 0.0184 | Win count 6
# Epoch 048/999 | Loss 0.0176 | Win count 7
# Epoch 049/999 | Loss 0.0299 | Win count 7
# Epoch 050/999 | Loss 0.0274 | Win count 7
# Epoch 051/999 | Loss 0.0222 | Win count 7
# Epoch 052/999 | Loss 0.0209 | Win count 7
# Epoch 053/999 | Loss 0.0206 | Win count 7
# Epoch 054/999 | Loss 0.0587 | Win count 7
# Epoch 055/999 | Loss 0.0277 | Win count 7
# Epoch 056/999 | Loss 0.0249 | Win count 7
# Epoch 057/999 | Loss 0.0158 | Win count 7
# Epoch 058/999 | Loss 0.0420 | Win count 8
# Epoch 059/999 | Loss 0.0305 | Win count 8
# Epoch 060/999 | Loss 0.0375 | Win count 8
# Epoch 061/999 | Loss 0.0264 | Win count 8
# Epoch 062/999 | Loss 0.0358 | Win count 9
# Epoch 063/999 | Loss 0.0324 | Win count 9
# Epoch 064/999 | Loss 0.0342 | Win count 9
# Epoch 065/999 | Loss 0.0285 | Win count 9
# Epoch 066/999 | Loss 0.0394 | Win count 9
# Epoch 067/999 | Loss 0.0401 | Win count 9
# Epoch 068/999 | Loss 0.0245 | Win count 9
# Epoch 069/999 | Loss 0.0211 | Win count 9
# Epoch 070/999 | Loss 0.0133 | Win count 9
# Epoch 071/999 | Loss 0.0415 | Win count 9
# Epoch 072/999 | Loss 0.0268 | Win count 9
# Epoch 073/999 | Loss 0.0367 | Win count 9
# Epoch 074/999 | Loss 0.0463 | Win count 9
# Epoch 075/999 | Loss 0.0351 | Win count 10
# Epoch 076/999 | Loss 0.0194 | Win count 10
# Epoch 077/999 | Loss 0.0214 | Win count 10
# Epoch 078/999 | Loss 0.0248 | Win count 10
# Epoch 079/999 | Loss 0.0294 | Win count 10
# Epoch 080/999 | Loss 0.0228 | Win count 10
# Epoch 081/999 | Loss 0.0378 | Win count 10
# Epoch 082/999 | Loss 0.0334 | Win count 10
# Epoch 083/999 | Loss 0.0226 | Win count 10
# Epoch 084/999 | Loss 0.0390 | Win count 10
# Epoch 085/999 | Loss 0.0399 | Win count 10
# Epoch 086/999 | Loss 0.0179 | Win count 10
# Epoch 087/999 | Loss 0.0284 | Win count 10
# Epoch 088/999 | Loss 0.0440 | Win count 10
# Epoch 089/999 | Loss 0.0305 | Win count 10
# Epoch 090/999 | Loss 0.0406 | Win count 10
# Epoch 091/999 | Loss 0.0305 | Win count 10
# Epoch 092/999 | Loss 0.0206 | Win count 10
# Epoch 093/999 | Loss 0.0152 | Win count 10
# Epoch 094/999 | Loss 0.0339 | Win count 10
# Epoch 095/999 | Loss 0.0113 | Win count 10
# Epoch 096/999 | Loss 0.0307 | Win count 10
# Epoch 097/999 | Loss 0.0312 | Win count 10
# Epoch 098/999 | Loss 0.0151 | Win count 10
# Epoch 099/999 | Loss 0.0197 | Win count 10
# Epoch 100/999 | Loss 0.0173 | Win count 10
# Epoch 101/999 | Loss 0.0245 | Win count 10
# Epoch 102/999 | Loss 0.0196 | Win count 10
# Epoch 103/999 | Loss 0.0194 | Win count 10
# Epoch 104/999 | Loss 0.0216 | Win count 10
# Epoch 105/999 | Loss 0.0244 | Win count 10
# Epoch 106/999 | Loss 0.0099 | Win count 10
# Epoch 107/999 | Loss 0.0139 | Win count 10
# Epoch 108/999 | Loss 0.0127 | Win count 10
# Epoch 109/999 | Loss 0.0098 | Win count 13
# Epoch 110/999 | Loss 0.0399 | Win count 18
# Epoch 111/999 | Loss 0.0450 | Win count 18
# Epoch 112/999 | Loss 0.0474 | Win count 19
# Epoch 113/999 | Loss 0.0331 | Win count 19
# Epoch 114/999 | Loss 0.0473 | Win count 19
# Epoch 115/999 | Loss 0.0478 | Win count 19
# Epoch 116/999 | Loss 0.0599 | Win count 19
# Epoch 117/999 | Loss 0.0656 | Win count 19
# Epoch 118/999 | Loss 0.0471 | Win count 19
# Epoch 119/999 | Loss 0.0337 | Win count 19
# Epoch 120/999 | Loss 0.0472 | Win count 19
# Epoch 121/999 | Loss 0.0312 | Win count 19
# Epoch 122/999 | Loss 0.0585 | Win count 19
# Epoch 123/999 | Loss 0.0455 | Win count 19
# Epoch 124/999 | Loss 0.0357 | Win count 19
# Epoch 125/999 | Loss 0.0314 | Win count 19
# Epoch 126/999 | Loss 0.0374 | Win count 19
# Epoch 127/999 | Loss 0.0271 | Win count 19
# Epoch 128/999 | Loss 0.0352 | Win count 19
# Epoch 129/999 | Loss 0.0217 | Win count 19
# Epoch 130/999 | Loss 0.0636 | Win count 22
# Epoch 131/999 | Loss 0.0634 | Win count 22
# Epoch 132/999 | Loss 0.0755 | Win count 24
# Epoch 133/999 | Loss 0.0830 | Win count 24
# Epoch 134/999 | Loss 0.0695 | Win count 24
# Epoch 135/999 | Loss 0.0655 | Win count 24
# Epoch 136/999 | Loss 0.0574 | Win count 24
# Epoch 137/999 | Loss 0.0631 | Win count 24
# Epoch 138/999 | Loss 0.0571 | Win count 24
# Epoch 139/999 | Loss 0.0808 | Win count 24
# Epoch 140/999 | Loss 0.0434 | Win count 24
# Epoch 141/999 | Loss 0.0644 | Win count 24
# Epoch 142/999 | Loss 0.0947 | Win count 24
# Epoch 143/999 | Loss 0.0687 | Win count 24
# Epoch 144/999 | Loss 0.0537 | Win count 24
# Epoch 145/999 | Loss 0.0669 | Win count 25
# Epoch 146/999 | Loss 0.0632 | Win count 25
# Epoch 147/999 | Loss 0.0675 | Win count 25
# Epoch 148/999 | Loss 0.0677 | Win count 25
# Epoch 149/999 | Loss 0.0467 | Win count 25
# Epoch 150/999 | Loss 0.0717 | Win count 25
# Epoch 151/999 | Loss 0.0607 | Win count 25
# Epoch 152/999 | Loss 0.0676 | Win count 25
# Epoch 153/999 | Loss 0.0661 | Win count 27
# Epoch 154/999 | Loss 0.0670 | Win count 27
# Epoch 155/999 | Loss 0.0847 | Win count 27
# Epoch 156/999 | Loss 0.0967 | Win count 27
# Epoch 157/999 | Loss 0.0692 | Win count 27
# Epoch 158/999 | Loss 0.0800 | Win count 27
# Epoch 159/999 | Loss 0.0619 | Win count 27
# Epoch 160/999 | Loss 0.0365 | Win count 27
# Epoch 161/999 | Loss 0.0502 | Win count 27
# Epoch 162/999 | Loss 0.0556 | Win count 27
# Epoch 163/999 | Loss 0.0557 | Win count 27
# Epoch 164/999 | Loss 0.0733 | Win count 27
# Epoch 165/999 | Loss 0.0340 | Win count 27
# Epoch 166/999 | Loss 0.0468 | Win count 27
# Epoch 167/999 | Loss 0.0512 | Win count 27
# Epoch 168/999 | Loss 0.0542 | Win count 27
# Epoch 169/999 | Loss 0.0516 | Win count 27
# Epoch 170/999 | Loss 0.0278 | Win count 27
# Epoch 171/999 | Loss 0.0416 | Win count 27
# Epoch 172/999 | Loss 0.0383 | Win count 27
# Epoch 173/999 | Loss 0.0449 | Win count 27
# Epoch 174/999 | Loss 0.0233 | Win count 27
# Epoch 175/999 | Loss 0.0679 | Win count 27
# Epoch 176/999 | Loss 0.0477 | Win count 27
# Epoch 177/999 | Loss 0.0462 | Win count 27
# Epoch 178/999 | Loss 0.0468 | Win count 27
# Epoch 179/999 | Loss 0.0342 | Win count 27
# Epoch 180/999 | Loss 0.0556 | Win count 29
# Epoch 181/999 | Loss 0.0474 | Win count 29
# Epoch 182/999 | Loss 0.0390 | Win count 29
# Epoch 183/999 | Loss 0.0244 | Win count 29
# Epoch 184/999 | Loss 0.0258 | Win count 29
# Epoch 185/999 | Loss 0.0264 | Win count 30
# Epoch 186/999 | Loss 0.0217 | Win count 30
# Epoch 187/999 | Loss 0.0467 | Win count 30
# Epoch 188/999 | Loss 0.0398 | Win count 30
# Epoch 189/999 | Loss 0.0397 | Win count 30
# Epoch 190/999 | Loss 0.0205 | Win count 30
# Epoch 191/999 | Loss 0.0323 | Win count 30
# Epoch 192/999 | Loss 0.0280 | Win count 30
# Epoch 193/999 | Loss 0.0380 | Win count 30
# Epoch 194/999 | Loss 0.0419 | Win count 30
# Epoch 195/999 | Loss 0.0304 | Win count 30
# Epoch 196/999 | Loss 0.0177 | Win count 30
# Epoch 197/999 | Loss 0.0208 | Win count 30
# Epoch 198/999 | Loss 0.0249 | Win count 30
# Epoch 199/999 | Loss 0.0254 | Win count 30
# Epoch 200/999 | Loss 0.0198 | Win count 30
# Epoch 201/999 | Loss 0.0250 | Win count 30
# Epoch 202/999 | Loss 0.0394 | Win count 31
# Epoch 203/999 | Loss 0.0244 | Win count 31
# Epoch 204/999 | Loss 0.0142 | Win count 31
# Epoch 205/999 | Loss 0.0236 | Win count 31
# Epoch 206/999 | Loss 0.0159 | Win count 31
# Epoch 207/999 | Loss 0.0166 | Win count 31
# Epoch 208/999 | Loss 0.0165 | Win count 31
# Epoch 209/999 | Loss 0.0242 | Win count 31
# Epoch 210/999 | Loss 0.0188 | Win count 32
# Epoch 211/999 | Loss 0.0119 | Win count 32
# Epoch 212/999 | Loss 0.0218 | Win count 33
# Epoch 213/999 | Loss 0.0277 | Win count 33
# Epoch 214/999 | Loss 0.0280 | Win count 33
# Epoch 215/999 | Loss 0.0314 | Win count 33
# Epoch 216/999 | Loss 0.0453 | Win count 33
# Epoch 217/999 | Loss 0.0350 | Win count 33
# Epoch 218/999 | Loss 0.0230 | Win count 35
# Epoch 219/999 | Loss 0.0404 | Win count 35
# Epoch 220/999 | Loss 0.0378 | Win count 35
# Epoch 221/999 | Loss 0.0372 | Win count 35
# Epoch 222/999 | Loss 0.0315 | Win count 35
# Epoch 223/999 | Loss 0.0470 | Win count 35
# Epoch 224/999 | Loss 0.0541 | Win count 35
# Epoch 225/999 | Loss 0.0232 | Win count 35
# Epoch 226/999 | Loss 0.0369 | Win count 35
# Epoch 227/999 | Loss 0.0587 | Win count 35
# Epoch 228/999 | Loss 0.0314 | Win count 35
# Epoch 229/999 | Loss 0.0519 | Win count 35
# Epoch 230/999 | Loss 0.0404 | Win count 36
# Epoch 231/999 | Loss 0.0277 | Win count 36
# Epoch 232/999 | Loss 0.0241 | Win count 36
# Epoch 233/999 | Loss 0.0218 | Win count 36
# Epoch 234/999 | Loss 0.0388 | Win count 36
# Epoch 235/999 | Loss 0.0227 | Win count 36
# Epoch 236/999 | Loss 0.0356 | Win count 36
# Epoch 237/999 | Loss 0.0147 | Win count 36
# Epoch 238/999 | Loss 0.0355 | Win count 36
# Epoch 239/999 | Loss 0.0277 | Win count 36
# Epoch 240/999 | Loss 0.0214 | Win count 36
# Epoch 241/999 | Loss 0.0547 | Win count 36
# Epoch 242/999 | Loss 0.0250 | Win count 36
# Epoch 243/999 | Loss 0.0274 | Win count 36
# Epoch 244/999 | Loss 0.0313 | Win count 36
# Epoch 245/999 | Loss 0.0541 | Win count 39
# Epoch 246/999 | Loss 0.0244 | Win count 39
# Epoch 247/999 | Loss 0.0466 | Win count 39
# Epoch 248/999 | Loss 0.0465 | Win count 39
# Epoch 249/999 | Loss 0.0291 | Win count 39
# Epoch 250/999 | Loss 0.0404 | Win count 39
# Epoch 251/999 | Loss 0.0433 | Win count 39
# Epoch 252/999 | Loss 0.0442 | Win count 39
# Epoch 253/999 | Loss 0.0484 | Win count 39
# Epoch 254/999 | Loss 0.0568 | Win count 39
# Epoch 255/999 | Loss 0.0451 | Win count 39
# Epoch 256/999 | Loss 0.0537 | Win count 39
# Epoch 257/999 | Loss 0.0408 | Win count 39
# Epoch 258/999 | Loss 0.0676 | Win count 39
# Epoch 259/999 | Loss 0.0347 | Win count 39
# Epoch 260/999 | Loss 0.0298 | Win count 39
# Epoch 261/999 | Loss 0.0432 | Win count 39
# Epoch 262/999 | Loss 0.0426 | Win count 39
# Epoch 263/999 | Loss 0.0404 | Win count 39
# Epoch 264/999 | Loss 0.0348 | Win count 39
# Epoch 265/999 | Loss 0.0329 | Win count 39
# Epoch 266/999 | Loss 0.0369 | Win count 39
# Epoch 267/999 | Loss 0.0243 | Win count 39
# Epoch 268/999 | Loss 0.0231 | Win count 39
# Epoch 269/999 | Loss 0.0412 | Win count 39
# Epoch 270/999 | Loss 0.0221 | Win count 39
# Epoch 271/999 | Loss 0.0264 | Win count 39
# Epoch 272/999 | Loss 0.0182 | Win count 39
# Epoch 273/999 | Loss 0.0155 | Win count 39
# Epoch 274/999 | Loss 0.0263 | Win count 39
# Epoch 275/999 | Loss 0.0237 | Win count 39
# Epoch 276/999 | Loss 0.0270 | Win count 39
# Epoch 277/999 | Loss 0.0231 | Win count 39
# Epoch 278/999 | Loss 0.0210 | Win count 39
# Epoch 279/999 | Loss 0.0164 | Win count 39
# Epoch 280/999 | Loss 0.0110 | Win count 39
# Epoch 281/999 | Loss 0.0113 | Win count 39
# Epoch 282/999 | Loss 0.0202 | Win count 39
# Epoch 283/999 | Loss 0.0184 | Win count 39
# Epoch 284/999 | Loss 0.0087 | Win count 39
# Epoch 285/999 | Loss 0.0202 | Win count 39
# Epoch 286/999 | Loss 0.0100 | Win count 39
# Epoch 287/999 | Loss 0.0145 | Win count 39
# Epoch 288/999 | Loss 0.0078 | Win count 39
# Epoch 289/999 | Loss 0.0071 | Win count 39
# Epoch 290/999 | Loss 0.0082 | Win count 39
# Epoch 291/999 | Loss 0.0058 | Win count 39
# Epoch 292/999 | Loss 0.0118 | Win count 39
# Epoch 293/999 | Loss 0.0137 | Win count 39
# Epoch 294/999 | Loss 0.0106 | Win count 39
# Epoch 295/999 | Loss 0.0087 | Win count 39
# Epoch 296/999 | Loss 0.0040 | Win count 39
# Epoch 297/999 | Loss 0.0040 | Win count 39
# Epoch 298/999 | Loss 0.0039 | Win count 39
# Epoch 299/999 | Loss 0.0030 | Win count 39
# Epoch 300/999 | Loss 0.0031 | Win count 39
# Epoch 301/999 | Loss 0.0032 | Win count 39
# Epoch 302/999 | Loss 0.0037 | Win count 39
# Epoch 303/999 | Loss 0.0036 | Win count 39
# Epoch 304/999 | Loss 0.0035 | Win count 39
# Epoch 305/999 | Loss 0.0037 | Win count 39
# Epoch 306/999 | Loss 0.0033 | Win count 39
# Epoch 307/999 | Loss 0.0026 | Win count 39
# Epoch 308/999 | Loss 0.0033 | Win count 39
# Epoch 309/999 | Loss 0.0025 | Win count 39
# Epoch 310/999 | Loss 0.0028 | Win count 39
# Epoch 311/999 | Loss 0.0029 | Win count 39
# Epoch 312/999 | Loss 0.0028 | Win count 39
# Epoch 313/999 | Loss 0.0029 | Win count 39
# Epoch 314/999 | Loss 0.0029 | Win count 39
# Epoch 315/999 | Loss 0.0025 | Win count 39
# Epoch 316/999 | Loss 0.0023 | Win count 39
# Epoch 317/999 | Loss 0.0023 | Win count 39
# Epoch 318/999 | Loss 0.0023 | Win count 39
# Epoch 319/999 | Loss 0.0021 | Win count 39
# Epoch 320/999 | Loss 0.0020 | Win count 39
# Epoch 321/999 | Loss 0.0022 | Win count 39
# Epoch 322/999 | Loss 0.0028 | Win count 39
# Epoch 323/999 | Loss 0.0024 | Win count 39
# Epoch 324/999 | Loss 0.0026 | Win count 39
# Epoch 325/999 | Loss 0.0022 | Win count 39
# Epoch 326/999 | Loss 0.0023 | Win count 39
# Epoch 327/999 | Loss 0.0023 | Win count 39
# Epoch 328/999 | Loss 0.0021 | Win count 39
# Epoch 329/999 | Loss 0.0025 | Win count 39
# Epoch 330/999 | Loss 0.0024 | Win count 39
# Epoch 331/999 | Loss 0.0019 | Win count 39
# Epoch 332/999 | Loss 0.0021 | Win count 39
# Epoch 333/999 | Loss 0.0022 | Win count 39
# Epoch 334/999 | Loss 0.0019 | Win count 39
# Epoch 335/999 | Loss 0.0019 | Win count 39
# Epoch 336/999 | Loss 0.0020 | Win count 39
# Epoch 337/999 | Loss 0.0020 | Win count 39
# Epoch 338/999 | Loss 0.0020 | Win count 39
# Epoch 339/999 | Loss 0.0020 | Win count 39
# Epoch 340/999 | Loss 0.0019 | Win count 39
# Epoch 341/999 | Loss 0.0027 | Win count 39
# Epoch 342/999 | Loss 0.0024 | Win count 39
# Epoch 343/999 | Loss 0.0021 | Win count 39
# Epoch 344/999 | Loss 0.0019 | Win count 39
# Epoch 345/999 | Loss 0.0022 | Win count 39
# Epoch 346/999 | Loss 0.0021 | Win count 39
# Epoch 347/999 | Loss 0.0021 | Win count 39
# Epoch 348/999 | Loss 0.0016 | Win count 39
# Epoch 349/999 | Loss 0.0020 | Win count 39
# Epoch 350/999 | Loss 0.0022 | Win count 39
# Epoch 351/999 | Loss 0.0020 | Win count 39
# Epoch 352/999 | Loss 0.0016 | Win count 39
# Epoch 353/999 | Loss 0.0013 | Win count 39
# Epoch 354/999 | Loss 0.0020 | Win count 39
# Epoch 355/999 | Loss 0.0019 | Win count 39
# Epoch 356/999 | Loss 0.0019 | Win count 39
# Epoch 357/999 | Loss 0.0028 | Win count 39
# Epoch 358/999 | Loss 0.0022 | Win count 39
# Epoch 359/999 | Loss 0.0023 | Win count 39
# Epoch 360/999 | Loss 0.0020 | Win count 39
# Epoch 361/999 | Loss 0.0025 | Win count 39
# Epoch 362/999 | Loss 0.0020 | Win count 39
# Epoch 363/999 | Loss 0.0021 | Win count 39
# Epoch 364/999 | Loss 0.0023 | Win count 39
# Epoch 365/999 | Loss 0.0022 | Win count 39
# Epoch 366/999 | Loss 0.0014 | Win count 39
# Epoch 367/999 | Loss 0.0018 | Win count 39
# Epoch 368/999 | Loss 0.0027 | Win count 39
# Epoch 369/999 | Loss 0.0024 | Win count 39
# Epoch 370/999 | Loss 0.0021 | Win count 39
# Epoch 371/999 | Loss 0.0021 | Win count 39
# Epoch 372/999 | Loss 0.0018 | Win count 39
# Epoch 373/999 | Loss 0.0020 | Win count 39
# Epoch 374/999 | Loss 0.0019 | Win count 39
# Epoch 375/999 | Loss 0.0022 | Win count 39
# Epoch 376/999 | Loss 0.0029 | Win count 39
# Epoch 377/999 | Loss 0.0020 | Win count 39
# Epoch 378/999 | Loss 0.0023 | Win count 39
# Epoch 379/999 | Loss 0.0031 | Win count 39
# Epoch 380/999 | Loss 0.0021 | Win count 39
# Epoch 381/999 | Loss 0.0020 | Win count 39
# Epoch 382/999 | Loss 0.0024 | Win count 39
# Epoch 383/999 | Loss 0.0018 | Win count 39
# Epoch 384/999 | Loss 0.0020 | Win count 39
# Epoch 385/999 | Loss 0.0021 | Win count 39
# Epoch 386/999 | Loss 0.0018 | Win count 39
# Epoch 387/999 | Loss 0.0023 | Win count 39
# Epoch 388/999 | Loss 0.0024 | Win count 39
# Epoch 389/999 | Loss 0.0026 | Win count 39
# Epoch 390/999 | Loss 0.0021 | Win count 39
# Epoch 391/999 | Loss 0.0026 | Win count 39
# Epoch 392/999 | Loss 0.0018 | Win count 39
# Epoch 393/999 | Loss 0.0019 | Win count 39
# Epoch 394/999 | Loss 0.0021 | Win count 39
# Epoch 395/999 | Loss 0.0024 | Win count 39
# Epoch 396/999 | Loss 0.0019 | Win count 39
# Epoch 397/999 | Loss 0.0024 | Win count 39
# Epoch 398/999 | Loss 0.0016 | Win count 39
# Epoch 399/999 | Loss 0.0025 | Win count 39
# Epoch 400/999 | Loss 0.0022 | Win count 39
# Epoch 401/999 | Loss 0.0021 | Win count 39
# Epoch 402/999 | Loss 0.0021 | Win count 39
# Epoch 403/999 | Loss 0.0019 | Win count 39
# Epoch 404/999 | Loss 0.0018 | Win count 39
# Epoch 405/999 | Loss 0.0019 | Win count 39
# Epoch 406/999 | Loss 0.0018 | Win count 39
# Epoch 407/999 | Loss 0.0017 | Win count 39
# Epoch 408/999 | Loss 0.0018 | Win count 39
# Epoch 409/999 | Loss 0.0015 | Win count 39
# Epoch 410/999 | Loss 0.0020 | Win count 39
# Epoch 411/999 | Loss 0.0016 | Win count 39
# Epoch 412/999 | Loss 0.0019 | Win count 39
# Epoch 413/999 | Loss 0.0023 | Win count 39
# Epoch 414/999 | Loss 0.0019 | Win count 39
# Epoch 415/999 | Loss 0.0022 | Win count 39
# Epoch 416/999 | Loss 0.0018 | Win count 39
# Epoch 417/999 | Loss 0.0017 | Win count 39
# Epoch 418/999 | Loss 0.0016 | Win count 39
# Epoch 419/999 | Loss 0.0016 | Win count 39
# Epoch 420/999 | Loss 0.0018 | Win count 39
# Epoch 421/999 | Loss 0.0021 | Win count 39
# Epoch 422/999 | Loss 0.0017 | Win count 39
# Epoch 423/999 | Loss 0.0017 | Win count 39
# Epoch 424/999 | Loss 0.0015 | Win count 39
# Epoch 425/999 | Loss 0.0014 | Win count 39
# Epoch 426/999 | Loss 0.0017 | Win count 39
# Epoch 427/999 | Loss 0.0017 | Win count 39
# Epoch 428/999 | Loss 0.0017 | Win count 39
# Epoch 429/999 | Loss 0.0022 | Win count 39
# Epoch 430/999 | Loss 0.0017 | Win count 39
# Epoch 431/999 | Loss 0.0015 | Win count 39
# Epoch 432/999 | Loss 0.0018 | Win count 39
# Epoch 433/999 | Loss 0.0015 | Win count 39
# Epoch 434/999 | Loss 0.0017 | Win count 39
# Epoch 435/999 | Loss 0.0021 | Win count 39
# Epoch 436/999 | Loss 0.0020 | Win count 39
# Epoch 437/999 | Loss 0.0021 | Win count 39
# Epoch 438/999 | Loss 0.0019 | Win count 39
# Epoch 439/999 | Loss 0.0020 | Win count 39
# Epoch 440/999 | Loss 0.0019 | Win count 39
# Epoch 441/999 | Loss 0.0013 | Win count 39
# Epoch 442/999 | Loss 0.0019 | Win count 39
# Epoch 443/999 | Loss 0.0068 | Win count 40
# Epoch 444/999 | Loss 0.0073 | Win count 40
# Epoch 445/999 | Loss 0.0072 | Win count 40
# Epoch 446/999 | Loss 0.0071 | Win count 40
# Epoch 447/999 | Loss 0.0074 | Win count 40
# Epoch 448/999 | Loss 0.0123 | Win count 40
# Epoch 449/999 | Loss 0.0026 | Win count 40
# Epoch 450/999 | Loss 0.0119 | Win count 40
# Epoch 451/999 | Loss 0.0017 | Win count 40
# Epoch 452/999 | Loss 0.0066 | Win count 40
# Epoch 453/999 | Loss 0.0068 | Win count 40
# Epoch 454/999 | Loss 0.0017 | Win count 40
# Epoch 455/999 | Loss 0.0063 | Win count 40
# Epoch 456/999 | Loss 0.0017 | Win count 40
# Epoch 457/999 | Loss 0.0017 | Win count 40
# Epoch 458/999 | Loss 0.0016 | Win count 40
# Epoch 459/999 | Loss 0.0019 | Win count 40
# Epoch 460/999 | Loss 0.0116 | Win count 40
# Epoch 461/999 | Loss 0.0164 | Win count 40
# Epoch 462/999 | Loss 0.0065 | Win count 40
# Epoch 463/999 | Loss 0.0189 | Win count 41
# Epoch 464/999 | Loss 0.0215 | Win count 41
# Epoch 465/999 | Loss 0.0156 | Win count 41
# Epoch 466/999 | Loss 0.0095 | Win count 41
# Epoch 467/999 | Loss 0.0038 | Win count 41
# Epoch 468/999 | Loss 0.0075 | Win count 41
# Epoch 469/999 | Loss 0.0165 | Win count 41
# Epoch 470/999 | Loss 0.0069 | Win count 41
# Epoch 471/999 | Loss 0.0120 | Win count 41
# Epoch 472/999 | Loss 0.0119 | Win count 41
# Epoch 473/999 | Loss 0.0119 | Win count 41
# Epoch 474/999 | Loss 0.0123 | Win count 42
# Epoch 475/999 | Loss 0.0074 | Win count 43
# Epoch 476/999 | Loss 0.0155 | Win count 43
# Epoch 477/999 | Loss 0.0213 | Win count 43
# Epoch 478/999 | Loss 0.0231 | Win count 43
# Epoch 479/999 | Loss 0.0101 | Win count 43
# Epoch 480/999 | Loss 0.0251 | Win count 43
# Epoch 481/999 | Loss 0.0153 | Win count 43
# Epoch 482/999 | Loss 0.0255 | Win count 43
# Epoch 483/999 | Loss 0.0027 | Win count 43
# Epoch 484/999 | Loss 0.0211 | Win count 43
# Epoch 485/999 | Loss 0.0166 | Win count 43
# Epoch 486/999 | Loss 0.0055 | Win count 43
# Epoch 487/999 | Loss 0.0117 | Win count 43
# Epoch 488/999 | Loss 0.0296 | Win count 43
# Epoch 489/999 | Loss 0.0299 | Win count 43
# Epoch 490/999 | Loss 0.0160 | Win count 43
# Epoch 491/999 | Loss 0.0256 | Win count 43
# Epoch 492/999 | Loss 0.0213 | Win count 43
# Epoch 493/999 | Loss 0.0110 | Win count 43
# Epoch 494/999 | Loss 0.0032 | Win count 43
# Epoch 495/999 | Loss 0.0156 | Win count 43
# Epoch 496/999 | Loss 0.0234 | Win count 43
# Epoch 497/999 | Loss 0.0210 | Win count 43
# Epoch 498/999 | Loss 0.0146 | Win count 43
# Epoch 499/999 | Loss 0.0139 | Win count 43
# Epoch 500/999 | Loss 0.0058 | Win count 43
# Epoch 501/999 | Loss 0.0291 | Win count 43
# Epoch 502/999 | Loss 0.0233 | Win count 43
# Epoch 503/999 | Loss 0.0211 | Win count 43
# Epoch 504/999 | Loss 0.0210 | Win count 43
# Epoch 505/999 | Loss 0.0145 | Win count 43
# Epoch 506/999 | Loss 0.0140 | Win count 43
# Epoch 507/999 | Loss 0.0028 | Win count 43
# Epoch 508/999 | Loss 0.0091 | Win count 43
# Epoch 509/999 | Loss 0.0081 | Win count 43
# Epoch 510/999 | Loss 0.0115 | Win count 43
# Epoch 511/999 | Loss 0.0130 | Win count 43
# Epoch 512/999 | Loss 0.0122 | Win count 43
# Epoch 513/999 | Loss 0.0032 | Win count 43
# Epoch 514/999 | Loss 0.0022 | Win count 43
# Epoch 515/999 | Loss 0.0106 | Win count 43
# Epoch 516/999 | Loss 0.0144 | Win count 43
# Epoch 517/999 | Loss 0.0116 | Win count 43
# Epoch 518/999 | Loss 0.0142 | Win count 43
# Epoch 519/999 | Loss 0.0197 | Win count 43
# Epoch 520/999 | Loss 0.0163 | Win count 43
# Epoch 521/999 | Loss 0.0106 | Win count 43
# Epoch 522/999 | Loss 0.0102 | Win count 43
# Epoch 523/999 | Loss 0.0108 | Win count 43
# Epoch 524/999 | Loss 0.0028 | Win count 43
# Epoch 525/999 | Loss 0.0029 | Win count 43
# Epoch 526/999 | Loss 0.0019 | Win count 43
# Epoch 527/999 | Loss 0.0021 | Win count 43
# Epoch 528/999 | Loss 0.0027 | Win count 43
# Epoch 529/999 | Loss 0.0021 | Win count 43
# Epoch 530/999 | Loss 0.0024 | Win count 44
# Epoch 531/999 | Loss 0.0020 | Win count 44
# Epoch 532/999 | Loss 0.0129 | Win count 44
# Epoch 533/999 | Loss 0.0025 | Win count 44
# Epoch 534/999 | Loss 0.0126 | Win count 44
# Epoch 535/999 | Loss 0.0080 | Win count 44
# Epoch 536/999 | Loss 0.0176 | Win count 44
# Epoch 537/999 | Loss 0.0121 | Win count 44
# Epoch 538/999 | Loss 0.0073 | Win count 44
# Epoch 539/999 | Loss 0.0024 | Win count 44
# Epoch 540/999 | Loss 0.0118 | Win count 44
# Epoch 541/999 | Loss 0.0069 | Win count 44
# Epoch 542/999 | Loss 0.0075 | Win count 44
# Epoch 543/999 | Loss 0.0072 | Win count 44
# Epoch 544/999 | Loss 0.0068 | Win count 44
# Epoch 545/999 | Loss 0.0112 | Win count 45
# Epoch 546/999 | Loss 0.0018 | Win count 45
# Epoch 547/999 | Loss 0.0068 | Win count 45
# Epoch 548/999 | Loss 0.0173 | Win count 45
# Epoch 549/999 | Loss 0.0127 | Win count 45
# Epoch 550/999 | Loss 0.0117 | Win count 45
# Epoch 551/999 | Loss 0.0222 | Win count 45
# Epoch 552/999 | Loss 0.0071 | Win count 45
# Epoch 553/999 | Loss 0.0120 | Win count 45
# Epoch 554/999 | Loss 0.0076 | Win count 45
# Epoch 555/999 | Loss 0.0117 | Win count 45
# Epoch 556/999 | Loss 0.0166 | Win count 45
# Epoch 557/999 | Loss 0.0068 | Win count 45
# Epoch 558/999 | Loss 0.0062 | Win count 45
# Epoch 559/999 | Loss 0.0076 | Win count 46
# Epoch 560/999 | Loss 0.0016 | Win count 46
# Epoch 561/999 | Loss 0.0270 | Win count 46
# Epoch 562/999 | Loss 0.0311 | Win count 46
# Epoch 563/999 | Loss 0.0216 | Win count 47
# Epoch 564/999 | Loss 0.0220 | Win count 47
# Epoch 565/999 | Loss 0.0020 | Win count 48
# Epoch 566/999 | Loss 0.0613 | Win count 48
# Epoch 567/999 | Loss 0.0286 | Win count 49
# Epoch 568/999 | Loss 0.0427 | Win count 50
# Epoch 569/999 | Loss 0.0309 | Win count 50
# Epoch 570/999 | Loss 0.0133 | Win count 50
# Epoch 571/999 | Loss 0.0322 | Win count 50
# Epoch 572/999 | Loss 0.0235 | Win count 50
# Epoch 573/999 | Loss 0.0176 | Win count 50
# Epoch 574/999 | Loss 0.0289 | Win count 50
# Epoch 575/999 | Loss 0.0425 | Win count 51
# Epoch 576/999 | Loss 0.0280 | Win count 51
# Epoch 577/999 | Loss 0.0228 | Win count 51
# Epoch 578/999 | Loss 0.0483 | Win count 51
# Epoch 579/999 | Loss 0.0213 | Win count 51
# Epoch 580/999 | Loss 0.0242 | Win count 51
# Epoch 581/999 | Loss 0.0337 | Win count 51
# Epoch 582/999 | Loss 0.0369 | Win count 51
# Epoch 583/999 | Loss 0.0522 | Win count 51
# Epoch 584/999 | Loss 0.0446 | Win count 51
# Epoch 585/999 | Loss 0.0326 | Win count 51
# Epoch 586/999 | Loss 0.0278 | Win count 51
# Epoch 587/999 | Loss 0.0399 | Win count 51
# Epoch 588/999 | Loss 0.0371 | Win count 51
# Epoch 589/999 | Loss 0.0354 | Win count 51
# Epoch 590/999 | Loss 0.0234 | Win count 51
# Epoch 591/999 | Loss 0.0340 | Win count 51
# Epoch 592/999 | Loss 0.0415 | Win count 51
# Epoch 593/999 | Loss 0.0552 | Win count 51
# Epoch 594/999 | Loss 0.0384 | Win count 51
# Epoch 595/999 | Loss 0.0344 | Win count 53
# Epoch 596/999 | Loss 0.0370 | Win count 53
# Epoch 597/999 | Loss 0.0543 | Win count 53
# Epoch 598/999 | Loss 0.0376 | Win count 53
# Epoch 599/999 | Loss 0.0375 | Win count 53
# Epoch 600/999 | Loss 0.0338 | Win count 53
# Epoch 601/999 | Loss 0.0335 | Win count 53
# Epoch 602/999 | Loss 0.0566 | Win count 53
# Epoch 603/999 | Loss 0.0333 | Win count 53
# Epoch 604/999 | Loss 0.0251 | Win count 53
# Epoch 605/999 | Loss 0.0423 | Win count 55
# Epoch 606/999 | Loss 0.0309 | Win count 55
# Epoch 607/999 | Loss 0.0370 | Win count 55
# Epoch 608/999 | Loss 0.0426 | Win count 55
# Epoch 609/999 | Loss 0.0608 | Win count 55
# Epoch 610/999 | Loss 0.0656 | Win count 55
# Epoch 611/999 | Loss 0.0658 | Win count 55
# Epoch 612/999 | Loss 0.0284 | Win count 55
# Epoch 613/999 | Loss 0.0388 | Win count 55
# Epoch 614/999 | Loss 0.0515 | Win count 56
# Epoch 615/999 | Loss 0.0427 | Win count 56
# Epoch 616/999 | Loss 0.0349 | Win count 56
# Epoch 617/999 | Loss 0.0318 | Win count 56
# Epoch 618/999 | Loss 0.0315 | Win count 56
# Epoch 619/999 | Loss 0.0553 | Win count 56
# Epoch 620/999 | Loss 0.0329 | Win count 56
# Epoch 621/999 | Loss 0.0416 | Win count 56
# Epoch 622/999 | Loss 0.0264 | Win count 56
# Epoch 623/999 | Loss 0.0513 | Win count 58
# Epoch 624/999 | Loss 0.0539 | Win count 58
# Epoch 625/999 | Loss 0.0296 | Win count 58
# Epoch 626/999 | Loss 0.0297 | Win count 59
# Epoch 627/999 | Loss 0.0383 | Win count 59
# Epoch 628/999 | Loss 0.0242 | Win count 59
# Epoch 629/999 | Loss 0.0436 | Win count 59
# Epoch 630/999 | Loss 0.0347 | Win count 59
# Epoch 631/999 | Loss 0.0375 | Win count 59
# Epoch 632/999 | Loss 0.0478 | Win count 59
# Epoch 633/999 | Loss 0.0427 | Win count 59
# Epoch 634/999 | Loss 0.0278 | Win count 59
# Epoch 635/999 | Loss 0.0609 | Win count 59
# Epoch 636/999 | Loss 0.0443 | Win count 59
# Epoch 637/999 | Loss 0.0339 | Win count 59
# Epoch 638/999 | Loss 0.0493 | Win count 59
# Epoch 639/999 | Loss 0.0230 | Win count 59
# Epoch 640/999 | Loss 0.0494 | Win count 59
# Epoch 641/999 | Loss 0.0460 | Win count 64
# Epoch 642/999 | Loss 0.0691 | Win count 64
# Epoch 643/999 | Loss 0.0887 | Win count 64
# Epoch 644/999 | Loss 0.0612 | Win count 64
# Epoch 645/999 | Loss 0.0360 | Win count 65
# Epoch 646/999 | Loss 0.0527 | Win count 65
# Epoch 647/999 | Loss 0.0880 | Win count 65
# Epoch 648/999 | Loss 0.0763 | Win count 65
# Epoch 649/999 | Loss 0.0571 | Win count 65
# Epoch 650/999 | Loss 0.0559 | Win count 65
# Epoch 651/999 | Loss 0.0719 | Win count 65
# Epoch 652/999 | Loss 0.0928 | Win count 65
# Epoch 653/999 | Loss 0.0627 | Win count 65
# Epoch 654/999 | Loss 0.0650 | Win count 66
# Epoch 655/999 | Loss 0.0642 | Win count 66
# Epoch 656/999 | Loss 0.0590 | Win count 66
# Epoch 657/999 | Loss 0.0806 | Win count 71
# Epoch 658/999 | Loss 0.1032 | Win count 71
# Epoch 659/999 | Loss 0.0836 | Win count 71
# Epoch 660/999 | Loss 0.0396 | Win count 71
# Epoch 661/999 | Loss 0.0686 | Win count 72
# Epoch 662/999 | Loss 0.0858 | Win count 72
# Epoch 663/999 | Loss 0.0721 | Win count 72
# Epoch 664/999 | Loss 0.0863 | Win count 72
# Epoch 665/999 | Loss 0.0509 | Win count 72
# Epoch 666/999 | Loss 0.0630 | Win count 73
# Epoch 667/999 | Loss 0.1030 | Win count 73
# Epoch 668/999 | Loss 0.0805 | Win count 73
# Epoch 669/999 | Loss 0.0901 | Win count 73
# Epoch 670/999 | Loss 0.0619 | Win count 73
# Epoch 671/999 | Loss 0.0875 | Win count 73
# Epoch 672/999 | Loss 0.0944 | Win count 73
# Epoch 673/999 | Loss 0.0793 | Win count 73
# Epoch 674/999 | Loss 0.0914 | Win count 73
# Epoch 675/999 | Loss 0.0720 | Win count 73
# Epoch 676/999 | Loss 0.1013 | Win count 74
# Epoch 677/999 | Loss 0.0879 | Win count 74
# Epoch 678/999 | Loss 0.0492 | Win count 74
# Epoch 679/999 | Loss 0.1074 | Win count 74
# Epoch 680/999 | Loss 0.1153 | Win count 74
# Epoch 681/999 | Loss 0.0442 | Win count 74
# Epoch 682/999 | Loss 0.0522 | Win count 74
# Epoch 683/999 | Loss 0.0732 | Win count 74
# Epoch 684/999 | Loss 0.0696 | Win count 74
# Epoch 685/999 | Loss 0.0807 | Win count 74
# Epoch 686/999 | Loss 0.0734 | Win count 74
# Epoch 687/999 | Loss 0.0785 | Win count 74
# Epoch 688/999 | Loss 0.0730 | Win count 74
# Epoch 689/999 | Loss 0.0760 | Win count 74
# Epoch 690/999 | Loss 0.0534 | Win count 74
# Epoch 691/999 | Loss 0.0495 | Win count 74
# Epoch 692/999 | Loss 0.0560 | Win count 74
# Epoch 693/999 | Loss 0.0462 | Win count 74
# Epoch 694/999 | Loss 0.0332 | Win count 74
# Epoch 695/999 | Loss 0.0185 | Win count 74
# Epoch 696/999 | Loss 0.0547 | Win count 74
# Epoch 697/999 | Loss 0.0326 | Win count 74
# Epoch 698/999 | Loss 0.0733 | Win count 74
# Epoch 699/999 | Loss 0.0298 | Win count 74
# Epoch 700/999 | Loss 0.0441 | Win count 74
# Epoch 701/999 | Loss 0.0414 | Win count 74
# Epoch 702/999 | Loss 0.0433 | Win count 74
# Epoch 703/999 | Loss 0.0646 | Win count 74
# Epoch 704/999 | Loss 0.0465 | Win count 74
# Epoch 705/999 | Loss 0.0559 | Win count 74
# Epoch 706/999 | Loss 0.0229 | Win count 74
# Epoch 707/999 | Loss 0.0129 | Win count 74
# Epoch 708/999 | Loss 0.0333 | Win count 74
# Epoch 709/999 | Loss 0.0159 | Win count 75
# Epoch 710/999 | Loss 0.0206 | Win count 75
# Epoch 711/999 | Loss 0.0157 | Win count 75
# Epoch 712/999 | Loss 0.0172 | Win count 75
# Epoch 713/999 | Loss 0.0214 | Win count 75
# Epoch 714/999 | Loss 0.0221 | Win count 75
# Epoch 715/999 | Loss 0.0110 | Win count 75
# Epoch 716/999 | Loss 0.0063 | Win count 75
# Epoch 717/999 | Loss 0.0215 | Win count 75
# Epoch 718/999 | Loss 0.0156 | Win count 75
# Epoch 719/999 | Loss 0.0122 | Win count 75
# Epoch 720/999 | Loss 0.0068 | Win count 75
# Epoch 721/999 | Loss 0.0143 | Win count 75
# Epoch 722/999 | Loss 0.0138 | Win count 75
# Epoch 723/999 | Loss 0.0218 | Win count 76
# Epoch 724/999 | Loss 0.0107 | Win count 76
# Epoch 725/999 | Loss 0.0220 | Win count 76
# Epoch 726/999 | Loss 0.0224 | Win count 76
# Epoch 727/999 | Loss 0.0161 | Win count 76
# Epoch 728/999 | Loss 0.0122 | Win count 76
# Epoch 729/999 | Loss 0.0155 | Win count 76
# Epoch 730/999 | Loss 0.0203 | Win count 76
# Epoch 731/999 | Loss 0.0309 | Win count 77
# Epoch 732/999 | Loss 0.0215 | Win count 77
# Epoch 733/999 | Loss 0.0099 | Win count 77
# Epoch 734/999 | Loss 0.0200 | Win count 77
# Epoch 735/999 | Loss 0.0201 | Win count 77
# Epoch 736/999 | Loss 0.0158 | Win count 77
# Epoch 737/999 | Loss 0.0377 | Win count 77
# Epoch 738/999 | Loss 0.0256 | Win count 77
# Epoch 739/999 | Loss 0.0347 | Win count 77
# Epoch 740/999 | Loss 0.0057 | Win count 77
# Epoch 741/999 | Loss 0.0230 | Win count 78
# Epoch 742/999 | Loss 0.0345 | Win count 78
# Epoch 743/999 | Loss 0.0104 | Win count 78
# Epoch 744/999 | Loss 0.0195 | Win count 78
# Epoch 745/999 | Loss 0.0280 | Win count 78
# Epoch 746/999 | Loss 0.0289 | Win count 78
# Epoch 747/999 | Loss 0.0188 | Win count 78
# Epoch 748/999 | Loss 0.0172 | Win count 78
# Epoch 749/999 | Loss 0.0244 | Win count 79
# Epoch 750/999 | Loss 0.0207 | Win count 79
# Epoch 751/999 | Loss 0.0209 | Win count 79
# Epoch 752/999 | Loss 0.0221 | Win count 79
# Epoch 753/999 | Loss 0.0227 | Win count 79
# Epoch 754/999 | Loss 0.0244 | Win count 79
# Epoch 755/999 | Loss 0.0181 | Win count 79
# Epoch 756/999 | Loss 0.0295 | Win count 79
# Epoch 757/999 | Loss 0.0299 | Win count 79
# Epoch 758/999 | Loss 0.0315 | Win count 79
# Epoch 759/999 | Loss 0.0347 | Win count 79
# Epoch 760/999 | Loss 0.0259 | Win count 79
# Epoch 761/999 | Loss 0.0045 | Win count 79
# Epoch 762/999 | Loss 0.0317 | Win count 79
# Epoch 763/999 | Loss 0.0338 | Win count 79
# Epoch 764/999 | Loss 0.0231 | Win count 79
# Epoch 765/999 | Loss 0.0244 | Win count 79
# Epoch 766/999 | Loss 0.0329 | Win count 79
# Epoch 767/999 | Loss 0.0300 | Win count 79
# Epoch 768/999 | Loss 0.0275 | Win count 79
# Epoch 769/999 | Loss 0.0235 | Win count 79
# Epoch 770/999 | Loss 0.0240 | Win count 79
# Epoch 771/999 | Loss 0.0372 | Win count 79
# Epoch 772/999 | Loss 0.0312 | Win count 80
# Epoch 773/999 | Loss 0.0271 | Win count 80
# Epoch 774/999 | Loss 0.0037 | Win count 80
# Epoch 775/999 | Loss 0.0328 | Win count 80
# Epoch 776/999 | Loss 0.0166 | Win count 80
# Epoch 777/999 | Loss 0.0164 | Win count 80
# Epoch 778/999 | Loss 0.0122 | Win count 80
# Epoch 779/999 | Loss 0.0118 | Win count 80
# Epoch 780/999 | Loss 0.0112 | Win count 80
# Epoch 781/999 | Loss 0.0209 | Win count 80
# Epoch 782/999 | Loss 0.0235 | Win count 80
# Epoch 783/999 | Loss 0.0117 | Win count 80
# Epoch 784/999 | Loss 0.0262 | Win count 80
# Epoch 785/999 | Loss 0.0030 | Win count 80
# Epoch 786/999 | Loss 0.0198 | Win count 80
# Epoch 787/999 | Loss 0.0195 | Win count 80
# Epoch 788/999 | Loss 0.0075 | Win count 80
# Epoch 789/999 | Loss 0.0163 | Win count 80
# Epoch 790/999 | Loss 0.0126 | Win count 80
# Epoch 791/999 | Loss 0.0163 | Win count 80
# Epoch 792/999 | Loss 0.0110 | Win count 80
# Epoch 793/999 | Loss 0.0068 | Win count 80
# Epoch 794/999 | Loss 0.0120 | Win count 80
# Epoch 795/999 | Loss 0.0163 | Win count 80
# Epoch 796/999 | Loss 0.0031 | Win count 80
# Epoch 797/999 | Loss 0.0026 | Win count 80
# Epoch 798/999 | Loss 0.0189 | Win count 80
# Epoch 799/999 | Loss 0.0101 | Win count 80
# Epoch 800/999 | Loss 0.0027 | Win count 81
# Epoch 801/999 | Loss 0.0116 | Win count 81
# Epoch 802/999 | Loss 0.0075 | Win count 82
# Epoch 803/999 | Loss 0.0079 | Win count 82
# Epoch 804/999 | Loss 0.0103 | Win count 82
# Epoch 805/999 | Loss 0.0210 | Win count 82
# Epoch 806/999 | Loss 0.0200 | Win count 82
# Epoch 807/999 | Loss 0.0162 | Win count 82
# Epoch 808/999 | Loss 0.0105 | Win count 82
# Epoch 809/999 | Loss 0.0169 | Win count 82
# Epoch 810/999 | Loss 0.0029 | Win count 82
# Epoch 811/999 | Loss 0.0218 | Win count 85
# Epoch 812/999 | Loss 0.0193 | Win count 85
# Epoch 813/999 | Loss 0.0484 | Win count 86
# Epoch 814/999 | Loss 0.0473 | Win count 86
# Epoch 815/999 | Loss 0.0323 | Win count 86
# Epoch 816/999 | Loss 0.0255 | Win count 86
# Epoch 817/999 | Loss 0.0477 | Win count 86
# Epoch 818/999 | Loss 0.0360 | Win count 86
# Epoch 819/999 | Loss 0.0495 | Win count 86
# Epoch 820/999 | Loss 0.0300 | Win count 86
# Epoch 821/999 | Loss 0.0516 | Win count 86
# Epoch 822/999 | Loss 0.0361 | Win count 86
# Epoch 823/999 | Loss 0.0350 | Win count 86
# Epoch 824/999 | Loss 0.0340 | Win count 86
# Epoch 825/999 | Loss 0.0394 | Win count 86
# Epoch 826/999 | Loss 0.0228 | Win count 86
# Epoch 827/999 | Loss 0.0174 | Win count 86
# Epoch 828/999 | Loss 0.0281 | Win count 86
# Epoch 829/999 | Loss 0.0333 | Win count 86
# Epoch 830/999 | Loss 0.0335 | Win count 86
# Epoch 831/999 | Loss 0.0361 | Win count 86
# Epoch 832/999 | Loss 0.0210 | Win count 86
# Epoch 833/999 | Loss 0.0197 | Win count 86
# Epoch 834/999 | Loss 0.0386 | Win count 86
# Epoch 835/999 | Loss 0.0325 | Win count 86
# Epoch 836/999 | Loss 0.0237 | Win count 86
# Epoch 837/999 | Loss 0.0148 | Win count 86
# Epoch 838/999 | Loss 0.0309 | Win count 86
# Epoch 839/999 | Loss 0.0356 | Win count 86
# Epoch 840/999 | Loss 0.0288 | Win count 86
# Epoch 841/999 | Loss 0.0147 | Win count 86
# Epoch 842/999 | Loss 0.0383 | Win count 86
# Epoch 843/999 | Loss 0.0155 | Win count 86
# Epoch 844/999 | Loss 0.0194 | Win count 86
# Epoch 845/999 | Loss 0.0302 | Win count 86
# Epoch 846/999 | Loss 0.0195 | Win count 86
# Epoch 847/999 | Loss 0.0305 | Win count 86
# Epoch 848/999 | Loss 0.0319 | Win count 86
# Epoch 849/999 | Loss 0.0314 | Win count 86
# Epoch 850/999 | Loss 0.0272 | Win count 86
# Epoch 851/999 | Loss 0.0207 | Win count 86
# Epoch 852/999 | Loss 0.0127 | Win count 86
# Epoch 853/999 | Loss 0.0166 | Win count 86
# Epoch 854/999 | Loss 0.0106 | Win count 86
# Epoch 855/999 | Loss 0.0136 | Win count 86
# Epoch 856/999 | Loss 0.0258 | Win count 86
# Epoch 857/999 | Loss 0.0171 | Win count 86
# Epoch 858/999 | Loss 0.0111 | Win count 86
# Epoch 859/999 | Loss 0.0183 | Win count 86
# Epoch 860/999 | Loss 0.0079 | Win count 86
# Epoch 861/999 | Loss 0.0052 | Win count 86
# Epoch 862/999 | Loss 0.0152 | Win count 86
# Epoch 863/999 | Loss 0.0081 | Win count 87
# Epoch 864/999 | Loss 0.0118 | Win count 87
# Epoch 865/999 | Loss 0.0038 | Win count 87
# Epoch 866/999 | Loss 0.0111 | Win count 87
# Epoch 867/999 | Loss 0.0152 | Win count 87
# Epoch 868/999 | Loss 0.0030 | Win count 87
# Epoch 869/999 | Loss 0.0153 | Win count 87
# Epoch 870/999 | Loss 0.0155 | Win count 87
# Epoch 871/999 | Loss 0.0072 | Win count 87
# Epoch 872/999 | Loss 0.0070 | Win count 87
# Epoch 873/999 | Loss 0.0028 | Win count 87
# Epoch 874/999 | Loss 0.0032 | Win count 87
# Epoch 875/999 | Loss 0.0033 | Win count 87
# Epoch 876/999 | Loss 0.0071 | Win count 87
# Epoch 877/999 | Loss 0.0030 | Win count 87
# Epoch 878/999 | Loss 0.0070 | Win count 87
# Epoch 879/999 | Loss 0.0033 | Win count 87
# Epoch 880/999 | Loss 0.0031 | Win count 87
# Epoch 881/999 | Loss 0.0105 | Win count 87
# Epoch 882/999 | Loss 0.0067 | Win count 87
# Epoch 883/999 | Loss 0.0064 | Win count 87
# Epoch 884/999 | Loss 0.0110 | Win count 89
# Epoch 885/999 | Loss 0.0122 | Win count 89
# Epoch 886/999 | Loss 0.0108 | Win count 89
# Epoch 887/999 | Loss 0.0150 | Win count 89
# Epoch 888/999 | Loss 0.0070 | Win count 89
# Epoch 889/999 | Loss 0.0114 | Win count 89
# Epoch 890/999 | Loss 0.0284 | Win count 89
# Epoch 891/999 | Loss 0.0166 | Win count 89
# Epoch 892/999 | Loss 0.0160 | Win count 89
# Epoch 893/999 | Loss 0.0247 | Win count 89
# Epoch 894/999 | Loss 0.0120 | Win count 89
# Epoch 895/999 | Loss 0.0114 | Win count 89
# Epoch 896/999 | Loss 0.0230 | Win count 89
# Epoch 897/999 | Loss 0.0116 | Win count 89
# Epoch 898/999 | Loss 0.0275 | Win count 89
# Epoch 899/999 | Loss 0.0105 | Win count 89
# Epoch 900/999 | Loss 0.0034 | Win count 89
# Epoch 901/999 | Loss 0.0076 | Win count 89
# Epoch 902/999 | Loss 0.0159 | Win count 89
# Epoch 903/999 | Loss 0.0150 | Win count 89
# Epoch 904/999 | Loss 0.0152 | Win count 89
# Epoch 905/999 | Loss 0.0232 | Win count 90
# Epoch 906/999 | Loss 0.0102 | Win count 90
# Epoch 907/999 | Loss 0.0284 | Win count 90
# Epoch 908/999 | Loss 0.0074 | Win count 90
# Epoch 909/999 | Loss 0.0215 | Win count 91
# Epoch 910/999 | Loss 0.0169 | Win count 91
# Epoch 911/999 | Loss 0.0177 | Win count 91
# Epoch 912/999 | Loss 0.0145 | Win count 91
# Epoch 913/999 | Loss 0.0291 | Win count 91
# Epoch 914/999 | Loss 0.0201 | Win count 91
# Epoch 915/999 | Loss 0.0147 | Win count 91
# Epoch 916/999 | Loss 0.0188 | Win count 91
# Epoch 917/999 | Loss 0.0206 | Win count 91
# Epoch 918/999 | Loss 0.0177 | Win count 91
# Epoch 919/999 | Loss 0.0133 | Win count 91
# Epoch 920/999 | Loss 0.0174 | Win count 91
# Epoch 921/999 | Loss 0.0165 | Win count 91
# Epoch 922/999 | Loss 0.0158 | Win count 91
# Epoch 923/999 | Loss 0.0203 | Win count 91
# Epoch 924/999 | Loss 0.0122 | Win count 91
# Epoch 925/999 | Loss 0.0131 | Win count 91
# Epoch 926/999 | Loss 0.0113 | Win count 91
# Epoch 927/999 | Loss 0.0252 | Win count 91
# Epoch 928/999 | Loss 0.0174 | Win count 91
# Epoch 929/999 | Loss 0.0167 | Win count 91
# Epoch 930/999 | Loss 0.0195 | Win count 91
# Epoch 931/999 | Loss 0.0159 | Win count 91
# Epoch 932/999 | Loss 0.0329 | Win count 91
# Epoch 933/999 | Loss 0.0176 | Win count 91
# Epoch 934/999 | Loss 0.0071 | Win count 91
# Epoch 935/999 | Loss 0.0027 | Win count 91
# Epoch 936/999 | Loss 0.0097 | Win count 91
# Epoch 937/999 | Loss 0.0190 | Win count 91
# Epoch 938/999 | Loss 0.0124 | Win count 91
# Epoch 939/999 | Loss 0.0099 | Win count 91
# Epoch 940/999 | Loss 0.0054 | Win count 91
# Epoch 941/999 | Loss 0.0095 | Win count 91
# Epoch 942/999 | Loss 0.0092 | Win count 91
# Epoch 943/999 | Loss 0.0030 | Win count 91
# Epoch 944/999 | Loss 0.0122 | Win count 91
# Epoch 945/999 | Loss 0.0023 | Win count 91
# Epoch 946/999 | Loss 0.0027 | Win count 91
# Epoch 947/999 | Loss 0.0142 | Win count 91
# Epoch 948/999 | Loss 0.0069 | Win count 91
# Epoch 949/999 | Loss 0.0141 | Win count 91
# Epoch 950/999 | Loss 0.0162 | Win count 91
# Epoch 951/999 | Loss 0.0028 | Win count 91
# Epoch 952/999 | Loss 0.0071 | Win count 91
# Epoch 953/999 | Loss 0.0140 | Win count 91
# Epoch 954/999 | Loss 0.0091 | Win count 91
# Epoch 955/999 | Loss 0.0096 | Win count 92
# Epoch 956/999 | Loss 0.0077 | Win count 92
# Epoch 957/999 | Loss 0.0023 | Win count 92
# Epoch 958/999 | Loss 0.0121 | Win count 92
# Epoch 959/999 | Loss 0.0077 | Win count 92
# Epoch 960/999 | Loss 0.0165 | Win count 93
# Epoch 961/999 | Loss 0.0076 | Win count 93
# Epoch 962/999 | Loss 0.0021 | Win count 93
# Epoch 963/999 | Loss 0.0129 | Win count 93
# Epoch 964/999 | Loss 0.0115 | Win count 93
# Epoch 965/999 | Loss 0.0173 | Win count 93
# Epoch 966/999 | Loss 0.0222 | Win count 93
# Epoch 967/999 | Loss 0.0073 | Win count 93
# Epoch 968/999 | Loss 0.0159 | Win count 93
# Epoch 969/999 | Loss 0.0126 | Win count 93
# Epoch 970/999 | Loss 0.0147 | Win count 93
# Epoch 971/999 | Loss 0.0113 | Win count 93
# Epoch 972/999 | Loss 0.0064 | Win count 93
# Epoch 973/999 | Loss 0.0060 | Win count 93
# Epoch 974/999 | Loss 0.0110 | Win count 93
# Epoch 975/999 | Loss 0.0107 | Win count 93
# Epoch 976/999 | Loss 0.0190 | Win count 93
# Epoch 977/999 | Loss 0.0113 | Win count 93
# Epoch 978/999 | Loss 0.0105 | Win count 93
# Epoch 979/999 | Loss 0.0057 | Win count 93
# Epoch 980/999 | Loss 0.0109 | Win count 93
# Epoch 981/999 | Loss 0.0105 | Win count 93
# Epoch 982/999 | Loss 0.0024 | Win count 93
# Epoch 983/999 | Loss 0.0058 | Win count 93
# Epoch 984/999 | Loss 0.0061 | Win count 93
# Epoch 985/999 | Loss 0.0150 | Win count 93
# Epoch 986/999 | Loss 0.0060 | Win count 93
# Epoch 987/999 | Loss 0.0107 | Win count 93
# Epoch 988/999 | Loss 0.0095 | Win count 93
# Epoch 989/999 | Loss 0.0056 | Win count 93
# Epoch 990/999 | Loss 0.0270 | Win count 94
# Epoch 991/999 | Loss 0.0198 | Win count 94
# Epoch 992/999 | Loss 0.0092 | Win count 94
# Epoch 993/999 | Loss 0.0200 | Win count 94
# Epoch 994/999 | Loss 0.0190 | Win count 94
# Epoch 995/999 | Loss 0.0114 | Win count 94
# Epoch 996/999 | Loss 0.0266 | Win count 94
# Epoch 997/999 | Loss 0.0106 | Win count 95
# Epoch 998/999 | Loss 0.0119 | Win count 96
# Epoch 999/999 | Loss 0.0359 | Win count 96

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from keras.models import model_from_json


if __name__ == "__main__":
    # Make sure this grid size matches the value used fro training
    grid_size = 10

    with open("model.json", "r") as jfile:
        model = model_from_json(json.load(jfile))
    model.load_weights("model.h5")
    model.compile("sgd", "mse")

    # Define environment, game
    env = Catch(grid_size)
    c = 0
    for e in range(10):
        loss = 0.
        env.reset()
        game_over = False
        # get initial input
        input_t = env.observe()

        plt.imshow(input_t.reshape((grid_size,)*2),
                   interpolation='none', cmap='gray')
        plt.savefig("%03d.png" % c)
        c += 1
        while not game_over:
            input_tm1 = input_t

            # get next action
            q = model.predict(input_tm1)
            action = np.argmax(q[0])

            # apply action, get rewards and new state
            input_t, reward, game_over = env.act(action)

            plt.imshow(input_t.reshape((grid_size,)*2),
                       interpolation='none', cmap='gray')
            plt.savefig("%03d.png" % c)
            c += 1

# %% [markdown]
# ffmpeg -i %03d.png output.gif -vf fps=1
